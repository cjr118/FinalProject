# %%
##Link to dataset on website
##https://data.wprdc.org/dataset/allegheny-county-asbestos-permit/resource/0a5408a4-8358-4b14-9317-090db7c61fd9

##Imports
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

pd.read_csv("asbestos.csv")
# Out:
#      permit_number                                     s_name  \
# 0        PAA170318                      5334/5336 PENN AVENUE
# 1        PAA170319                              ONE PNC PLAZA
# 2        PAA170320                         915 LINCOLN AVENUE
# 3        PAA170321                          1035 KEENE AVENUE
# 4        PAA170322                        325 MURTLAND AVENUE
# ...            ...                                        ...
# 7524     PAA170313  JEFFERSON HOSPITAL - 565 COAL VALLEY ROAD
# 7525     PAA170314       UNIVERISTY OF PITTSBURGH POSVAR HALL
# 7526     PAA170315                    PITTSBURGH STERRETT 6-8
# 7527     PAA170316            SAINT THERESE OF LISIEUX SCHOOL
# 7528     PAA170317       STANDARD FORGE - AXLE REHEAT FURNACE
#
#               s_address             city   z_code  p_fee           c_number  \
# 0        5534  PENN AVE       PITTSBURGH  15206.0  850.0  M. O. 69673455236
# ...
